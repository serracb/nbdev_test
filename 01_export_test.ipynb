# %%
# default_exp export_test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from nbdev_test.core import read_image2

# %%
read_image2('image_test.jpeg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x7FC08CE84B70>

# %%
#export core
#export
def say_goodbye(name):
    return("goodbye "+name)

# %%
say_goodbye("serra")
# Out:
# 'goodbye serra'
